# %% [markdown]
# <a href="https://colab.research.google.com/github/otoniel-star/PNNAAT/blob/main/pnnat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # expressoes

# %%
a=7
b=3
c=5
d=2

# %%
expressao_complexa=((a*b)+(c/d))-(a**b)
print (expressao_complexa)
# Out:
# -319.5

# %%
x =10;
y=20;
z=30;
expressao_condicional = (x<y and y>z) or (x + y == z and not (z==x*3))
print (expressao_condicional)
# Out:
# False

# %%
m = 25;
n=35;
p =45;
expressao_relacional = ((m + n) > (p * 2)) and ((p/n) < m) or ( n == m + p)
print (expressao_relacional)
# Out:
# False

# %%
# Leitura dos valores (não altere estas linhas)
x = int(input())
y = int(input())
z = int(input())

# Escreva abaixo a expressão lógica e imprima o resultado (True ou False):
expressao =(x < y and y > z) or (x + y == z and not (z == x * 3))
print (expressao)
# Out:
# 10
# 30
# 40
# True

# %% [markdown]
# # Listas e tuplas

# %%
##CRIAÇÃO  E INICIALIZAÇÃO DE UMA LISTA PARA ARMAZENAR LEITURAS DE TEMPERATURAS.
temperatura_celsius = [25.1, 25.5, 24.9, 26.0, 25.8]
print(f"Leituras iniciais de temperatura: {temperatura_celsius}")
# Out:
# Leituras iniciais de temperatura: [25.1, 25.5, 24.9, 26.0, 25.8]

# %%
##adcionando novas leituras á lista
###função .append()
temperatura_celsius.append(26.2)
temperatura_celsius.append(25.7)
print(f"leitura após novas coletas: {temperatura_celsius}")
# Out:
# leitura após novas coletas: [25.1, 25.5, 24.9, 26.0, 25.8, 26.2, 25.7]

# %%
##3.acessando elementos especificos
primeira_leitura = temperatura_celsius[0]
ultima_leitura = temperatura_celsius[-1]#acessando ultimo elemento
print(f"primeira leitura registrada:{primeira_leitura} °C")
print(f"ultima leitura registrada:{ultima_leitura} °C")
# Out:
# primeira leitura registrada:25.1 °C
# ultima leitura registrada:25.7 °C

# %%
#4modificando leitura
temperatura_celsius[2]=25.0 #supondo que a terceira leitura (indice 2) foi corrigida
print(f"leituras após correção: {temperatura_celsius}")
# Out:
# leituras após correção: [25.1, 25.5, 25.0, 26.0, 25.8, 26.2, 25.7]

# %%
##5.Removendo uma leitura
temperatura_celsius.pop(0) #Remove o primeiro elemento(leitura mais antiga)
print (f"Leituras após remover a mais antiga: {temperatura_celsius}")
# Out:
# Leituras após remover a mais antiga: [25.0, 26.0, 25.8, 26.2, 25.7]

# %%
##6.Verificando o tamanho da lista
print (f"Número total de leituras registradas: {len(temperatura_celsius)}")
# Out:
# Número total de leituras registradas: 5

# %%
##7.verificando a existencia de um valor
if 26.2 in temperatura_celsius:
  print ("A temperatura de 26.2°c está registrada")
# Out:
# A temperatura de 26.2°c está registrada

# %%
##8.verificando a existencia e posição de um valor
temperatura_para_buscar = 26.2
if temperatura_para_buscar in temperatura_celsius:
  posicao = temperatura_celsius.index(temperatura_para_buscar)
  print(f"A temperatura de {temperatura_para_buscar}°C existe e está na posição (índice) {posicao} da lista.")
else:
  print(f"A temperatura de {temperatura_para_buscar}°C não está registrada na lista.")
# Out:
# A temperatura de 26.2°C existe e está na posição (índice) 3 da lista.

# %%
##8.ordenando as leituras
temperatura_celsius.sort()
print(f"leituras ordenadas:{temperatura_celsius}")
# Out:
# leituras ordenadas:[25.0, 25.7, 25.8, 26.0, 26.2]

# %% [markdown]
# # Dicionarios

# %%
##Criação e inicialização de um dicionário para armazenar estados de máquinas
estados_maquina ={
    "maquina_1": "operacional",
    "maquina_2": "manutenção",
    "maquina_3": "parada",
    "maquina_4": "operacional"
}
print(f"Estados iniciais de máquinas: {estados_maquina}")
# Out:
# Estados iniciais de máquinas: {'maquina_1': 'operacional', 'maquina_2': 'manutenção', 'maquina_3': 'parada', 'maquina_4': 'operacional'}

# %%
##adicionando novos estado áe  maquinas
estados_maquina.update({"maquina_5": "operacional"})
estados_maquina.update({"maquina_6": "manutenção"})
print(f"Estados após adcionar novas maquinas: {estados_maquina}")
# Out:
# Estados após adcionar novas maquinas: {'maquina_1': 'operacional', 'maquina_2': 'manutenção', 'maquina_3': 'parada', 'maquina_4': 'operacional', 'maquina_5': 'operacional', 'maquina_6': 'manutenção'}

# %%
##Acessando estados especificos
estado_maquina_1= estados_maquina["maquina_1"]
estado_maquina_3 = estados_maquina["maquina_3"]
print(f"Estado da maquina 1: {estado_maquina_1}")
print(f"Estado da maquina 3: {estado_maquina_3}")
# Out:
# Estado da maquina 1: operacional
# Estado da maquina 3: parada

# %%
##modificando um estado
estados_maquina["maquina_2"]= "operacional" #supondo que voltou a operacionar
print(f"Estados após atualização: {estados_maquina}")
# Out:
# Estados após atualização: {'maquina_1': 'operacional', 'maquina_2': 'operacional', 'maquina_3': 'parada', 'maquina_4': 'operacional', 'maquina_5': 'operacional', 'maquina_6': 'manutenção'}

# %%
##Removendo uma leitura:
del estados_maquina["maquina_3"] #Remove o estado da maquina 3 ('desativada')
print(f"Estados apos a remoção da do estado da maquina 3: {estados_maquina}")
# Out:
# Estados apos a remoção da do estado da maquina 3: {'maquina_1': 'operacional', 'maquina_2': 'operacional', 'maquina_4': 'operacional', 'maquina_5': 'operacional', 'maquina_6': 'manutenção'}

# %%
## Apagando o estado de uma máquina (sem removê-la)
estados_maquina["maquina_1"] = None # Define o estado da maquina_1 como None
print(f"Estados após 'apagar' o estado da máquina 1: {estados_maquina}")

# Outra opção seria usar uma string vazia:
# estados_maquina["maquina_2"] = ""
# print(f"Estados após 'apagar' o estado da máquina 2 com string vazia: {estados_maquina}")
# Out:
# Estados após 'apagar' o estado da máquina 1: {'maquina_1': None, 'maquina_2': 'operacional', 'maquina_4': 'operacional', 'maquina_5': 'operacional', 'maquina_6': 'manutenção'}

# %%
##verificando o tamanho do dicionario:
print(f"Número total de estados registrados: {len(estados_maquina)}")
# Out:
# Número total de estados registrados: 5

# %%
##listar todas as maquinas cadastradas
print(f"Máquinas atualmente registradas: {estados_maquina.keys()}")
# Out:
# Máquinass atualmente registradas: dict_keys(['maquina_1', 'maquina_2', 'maquina_4', 'maquina_5', 'maquina_6'])

# %%
##definindo um dicionario de comandos para as maquinas:
comandos_maquinas={
    "maquina_A": ["ligar", "monitorar","desligar"],
    "maquina_B": ["manutencao", "calibrar"],
    "maquina_c":["ligar","monitorar"],
    "maquina_D":["desligar","ligar"]
}
print(f"\nComandos para as máquinas: {comandos_maquinas}")
# Out:
# Comandos para as máquinas: {'maquina_A': ['ligar', 'monitorar', 'desligar'], 'maquina_B': ['manutencao', 'calibrar'], 'maquina_c': ['ligar', 'monitorar'], 'maquina_D': ['desligar', 'ligar']}

# %%
##Executando os proximos comandos para a maquina A
proximo_comando = comandos_maquinas['maquina_A'].pop(0)
print(f"Executando comando: {proximo_comando} para a maquina A")
print (f"Comandos restantes para a maquina A: {comandos_maquinas['maquina_A']}")
# Out:
# Executando comando: ligar para a maquina A
# Comandos restantes para a maquina A: ['monitorar', 'desligar']

# %% [markdown]
# #Estrutura condional
#
# > if, elif e else

# %%
# Estrutura condicional -if

temperatura = 30

if temperatura >25:
    print("Acionar ventilação")
# Out:
# Acionar ventilação

# %%
#estrutura condicional if, elif e else
temperatura = 30
if temperatura > 25:
  print("Acionar ventilação")
elif temperatura <15:
    print("aquecer ambiente!")
else:
    print("Sistema estável.")
# Out:
# Acionar ventilação

# %%
##logica condicional e fluxos de decisao
###exemplo 01 controle de nivel liquido

#simulação de leitura de nivel liquido
nivel_litros = 50 #nivel atual de liquido em litros
nivel_maximo = 100 #nivel maximo permitido em litros
nivel_minimo = 20 #nivel minimo seguro em litros

print (f"Nivel atual do liquido: {nivel_litros} litros")

#logica condicional para controle do nivel liquido
if nivel_litros > nivel_maximo:
  print("Atenção: nivel liquido acima do maximo! Acionando drenagem.")
elif nivel_litros < nivel_minimo:
  print("Atenção: nivel liquido abaixo do minimo! Acionando sistema de abastecimento")
else:
  print("Nivel do liquido dentro dos limites normais.")
# Out:
# Nivel atual do liquido: 50 litros
# Nivel do liquido dentro dos limites normais.

# %%
#exemplo 02 monitoramento de pressão
#simulando valores lidos
pressao_atual = 3.5 #pressão atual em bar
pressao_maxima = 5.0 #pressao maxima permitida em bar
pressao_minima = 1.0 #pressao minima permitida em bar

print (f"Pressão atual: {pressao_atual} bar")

#logica condicional para controle da pressão
if pressao_atual > pressao_maxima and pressao_atual > 4.0:
  print("Atenção pressao critica! acionando alivio de pressão.")
elif pressao_atual < pressao_minima or pressao_atual < 2.0:
  print ("atenção: pressão baixa! acionando compressão.")
else:
  print("Pressão dentro dos limites normais")
# Out:
# Pressão atual: 3.5 bar
# Pressão dentro dos limites normais

# %% [markdown]
# [desafios de python no hackerrank](https://www.hackerrank.com/challenges/py-if-else/problem)

# %% [markdown]
# [operadores em python](https://www.w3schools.com/python/python_operators.asp)

# %% [markdown]
# #Loops for e while

# %%
#exemplo de for

for i in range(10):
  print("Produto", i+1, "verificado.")
# Out:
# Produto 1 verificado.
# Produto 2 verificado.
# Produto 3 verificado.
# Produto 4 verificado.
# Produto 5 verificado.
# Produto 6 verificado.
# Produto 7 verificado.
# Produto 8 verificado.
# Produto 9 verificado.
# Produto 10 verificado.

# %%
#exemplo de for com listas
ordem = ["Segunda", "Terça", "Quarta", "Quinta", "Sexta", "Sabado", "Domingo"]
for x in ordem:
  print("Dia da semana:", x)
# Out:
# Dia da semana: Segunda
# Dia da semana: Terça
# Dia da semana: Quarta
# Dia da semana: Quinta
# Dia da semana: Sexta
# Dia da semana: Sabado
# Dia da semana: Domingo

# %%
#exemplo de while
#Temperatura inicial em graus celsius
temperatura = 20

#Enquanto a temperatura for menor ou igual a 25
while temperatura <=25:
  print(f"temperatura atual: {temperatura:.2f}°C")
  temperatura+=0.5 #aumenta a demperatura em 1 grau °c
# Out:
# temperatura atual: 20.00°C
# temperatura atual: 20.50°C
# temperatura atual: 21.00°C
# temperatura atual: 21.50°C
# temperatura atual: 22.00°C
# temperatura atual: 22.50°C
# temperatura atual: 23.00°C
# temperatura atual: 23.50°C
# temperatura atual: 24.00°C
# temperatura atual: 24.50°C
# temperatura atual: 25.00°C

# %% [markdown]
# Fluxos Iterativos e Laços de Repetição

# %%
##Parte 1 – Loop while: Monitoramento contínuo

#Importando biblioteca para simular tempo
import time

#definindo o consumo de energia inicial
consumo_energia = 50 #consumo inicial em kw
limite_superior = 100 #limite superior de consumo seguro em kw

#laços de repetição para monitorar o consumo de energia
while True:
  print(f"Consumo de energia atual: {consumo_energia} KW")
  if consumo_energia > limite_superior:
    print("Alerta: Consumo de energia acima do limite seguro!")
    break #sai do loop se o limite for ultrapassado
  #simulando variação de energia
  consumo_energia +=10 #aumenta o consumo em 10kw
  time.sleep(2) #Pausa de 2 segundo entre as leituras
print ("Monitoramento encerrado.")
# Out:
# Consumo de energia atual: 50 KW
# Consumo de energia atual: 60 KW
# Consumo de energia atual: 70 KW
# Consumo de energia atual: 80 KW
# Consumo de energia atual: 90 KW
# Consumo de energia atual: 100 KW
# Consumo de energia atual: 110 KW
# Alerta: Consumo de energia acima do limite seguro!
# Monitoramento encerrado.

# %%
##Parte 2 – Loop for: Iterando com range(), lista e dicionário

###Exemplo 1 – Usando for com range()
#O loop irá iterar de 1 a 5, representando cada ciclo de consumo

for ciclo in range(1, 6):
  #calculo do consumo de energia para o ciclo atual
  consumo_energia = 50 + (ciclo *8)
  #Exibe o ciclo e o respectivo consumo de energia em kw
  print(f"Ciclo{ciclo}: Consumo de energia = {consumo_energia} KW")
# Out:
# Ciclo1: Consumo de energia = 58 KW
# Ciclo2: Consumo de energia = 66 KW
# Ciclo3: Consumo de energia = 74 KW
# Ciclo4: Consumo de energia = 82 KW
# Ciclo5: Consumo de energia = 90 KW

# %%
# O loop irá gerar valores de 1 a 9, pulando de 2 em 2
for ciclo in range(1, 10, 2):  # A cada dois valores
    print(ciclo)  # Exibe o valor atual do ciclo
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
#Exemplo 02- usando for e listas
#Lista com dados simulados de consumo de energia
leituras = [55, 63, 70, 95, 105]

#itera sobre cada leitura na lista
for leitura in leituras:
  #verifica se a leitura de consumo excede o limite de 100 kw
  if leitura > 100:
    print(f"Alerta! consumo de {leitura} KW excedeu o limite!")
  else:
    print(f"consumo de {leitura} KW dentro do limite.")
# Out:
# consumo de 55 KW dentro do limite.
# consumo de 63 KW dentro do limite.
# consumo de 70 KW dentro do limite.
# consumo de 95 KW dentro do limite.
# Alerta! consumo de 105 KW excedeu o limite!

# %%
##Exemplo 3 – Usando for com dicionário
#dicionario contendo o consumo de energia em diferentes setores
consumo_setores = {
    "Produção": 88,
    "refrigeração":102,
    "Iluminacao":76
}

#Itera sobre cada setor e seu respectivo consumo de energia
for setor, consumo in consumo_setores.items():
  #determina o status do consumo com base no limite de 100 kw
  if consumo >100:
    status = "acima do limite"
  else:
    status = "dentro do limite"
  #exibe o setor, consumo e o status
  print (f"Setor: {setor} | Consumo: {consumo} kw- status: {status}")
# Out:
# Setor: Produção | Consumo: 88 kw- status: dentro do limite
# Setor: refrigeração | Consumo: 102 kw- status: acima do limite
# Setor: Iluminacao | Consumo: 76 kw- status: dentro do limite

# %% [markdown]
# >Análise da Lógica
# Combinamos loops while e for para simular cenários reais de monitoramento e análise de consumo energético:
#
# while: ideal para monitoramento contínuo com condição de parada.
# for com range(): útil para repetições com número conhecido de ciclos.
# for com lista: para percorrer coleções de dados.
# for com dicionário: para analisar dados relacionados (ex: setor x consumo).

# %% [markdown]
# [Laços de repetição](https://docs.python.org/pt-br/3/tutorial/controlflow.html#for-statements)

# %% [markdown]
# #Funções e modularização

# %%
#Função exibe temperatura
def exibir_temperatura(temp):
  print("Temperatura atual: ", temp)

#chamada
exibir_temperatura(27)
# Out:
# Temperatura atual:  27

# %%
#Função calcular média
def calcula_media(a,b):
  return(a+b)/2
#chamada
print("média: ",calcula_media(9,7))
# Out:
# média:  8.0

# %%
#função verifica vibração com limite 30
def alerta_vibracao(valor, limite = 30):
  if valor > limite:
    return " Vibração excessiva detectada!"
  return "tudo normal."

#chamadas
print(alerta_vibracao(45))#acima do limite
print(alerta_vibracao(15))#abaixo do limite
# Out:
#  Vibração excessiva detectada!
# tudo normal.

# %% [markdown]
# [Modulos no python](https://www.w3schools.com/python/python_modules.asp)

# %%
#Importamos os modulos que serão utilizados no nosso script
import math
import random
from datetime import datetime

#----constantes do modulo-----
diametro_engrenagem_mm = 50
circunferencia_engrenagem = math.pi * diametro_engrenagem_mm

#--Funções do modulo---
def simular_leitura_sensor():
  """Simula a leitura de sensores e atuador."""
  posicao_percentual = random.uniform(0,100) # Corrigido: `uniforme` para `uniform`
  temperatura_celsius = random.randint(25,80)
  return posicao_percentual, temperatura_celsius

def registrar_evento(posicao, temperatura):
  """cria registro (log) formatado com o status do atuador e um timestamp. """
  timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
  print(f"[{timestamp}] log atuador: posição = {posicao:.2f}%, temp = {temperatura} °C")

#logica principal do script
print("---Iniciando monitoramento simulado de atuador industrial ---")
print (f"configuração: circunferencia de engrenagem = {circunferencia_engrenagem:.2f} mm")
print ("-"*60)

#simula o monitoramento de cinco ciclos
for i in range(5):
  pos, temp = simular_leitura_sensor()
  registrar_evento(pos, temp)

  print("-"*60)
print("-----------fim do monitoramento---------")
# Out:
# ---Iniciando monitoramento simulado de atuador industrial ---
# configuração: circunferencia de engrenagem = 157.08 mm
# ------------------------------------------------------------
# [2026-07-19 05:21:23] log atuador: posição = 65.36%, temp = 70 °C
# ------------------------------------------------------------
# [2026-07-19 05:21:23] log atuador: posição = 56.97%, temp = 57 °C
# ------------------------------------------------------------
# [2026-07-19 05:21:23] log atuador: posição = 69.45%, temp = 40 °C
# ------------------------------------------------------------
# [2026-07-19 05:21:23] log atuador: posição = 97.61%, temp = 31 °C
# ------------------------------------------------------------
# [2026-07-19 05:21:23] log atuador: posição = 32.88%, temp = 66 °C
# ------------------------------------------------------------
# -----------fim do monitoramento---------

# %% [markdown]
# #Programação orientada a objetos com python
# #

# %%
#Conceito de classes e objetos em python
#Classes + construtor(__init__) com atributos

class sensorDeTemperatura:
  #O mètodo __init__ é o "construtor" da classe.
  #Ele define os atributos iniciais.

  def __init__(self, id_sensor, localizacao):
    self.id_sensor = id_sensor
    self.localizacao = localizacao
    self.temperatura_atual=0.0 #valor inicial padrao

# %%
#classe com metodo(ler_temperatura)

class SensorDeTemperatura:
  def __init__(self, id_sensor, localizacao):
    self.id_sensor = id_sensor
    self.localizacao = localizacao
    self.temperatura_atual = 0.0
  #Este é um metodo
  def ler_temperatura(self, nova_leitura):
    self.temperatura_atual = nova_leitura
    print(f"sensor{self.id_sensor}:temperatura atualizada para {self.temperatura_atual}°C")

# %%
#Objetos (instancias) e acesso aos tributos

#criando objetos (instancias) a partir da classe SensorDeTemperatura
sensor_01 = SensorDeTemperatura ("ID-A01","Motor principal")
sensor_02 = SensorDeTemperatura ("ID-B02", "esteira de saida")

#cada objeto tem seus proprios dados (atributos)
print(f"Sensor: {sensor_01.id_sensor}, Local: {sensor_01.localizacao}")
print (f"Sensor: {sensor_02.id_sensor}, Local: {sensor_02.localizacao}")

#exemplo de uso de metodo
sensor_01.ler_temperatura(28.6)
sensor_02.ler_temperatura(31.2)
# Out:
# Sensor: ID-A01, Local: Motor principal
# Sensor: ID-B02, Local: esteira de saida
# sensorID-A01:temperatura atualizada para 28.6°C
# sensorID-B02:temperatura atualizada para 31.2°C

# %% [markdown]
# *Propriedades e Comportamentos de Objetos

# %%
#codigo exemplo
class RoboIndustrial:
  #o metodo construtor que define os atributos iniciais
  def __init__(self,id_robo, ferramenta_inicial):
    #Atributos (Proprieddades) do objeto
    self.id_robo = id_robo
    self.ferramenta_atual = ferramenta_inicial
    self.status = "em espera" #um status padrao

  #Método(comportamento) para mudar o status
  def ativar(self):
    print(f"Robo {self.id_robo} ativado!")
    self.status = "ativo" #o metodo altera o proprio atributo do objeto

  #Método para trocar a ferramenta
  def trocar_ferramenta(self, nova_ferramenta):
    self.ferramenta_atual = nova_ferramenta
    print(f"Robo {self.id_robo}: trocando ferramenta para a ferramenta: {self.ferramenta_atual}")

#Criando duas instancias (objetos da classse RoboIndustrial)
robo_A = RoboIndustrial("R-A01", "garra")
robo_B = RoboIndustrial("R-B02", "soldador")

#verificando os atributos iniciais de cada um
print(f"Status inicial do {robo_A.id_robo}: {robo_A.status}")
print(f"Status inicial do {robo_B.id_robo}: {robo_B.status}")

#Agora vamos vazer o robo_A realizar uma ação
robo_A.ativar()

#Verificando os status novamente
print(f"Status atual do {robo_A.id_robo}: {robo_A.status}")
print(f"Status atual do {robo_B.id_robo}: (não foi alterado): {robo_B.status}")
# Out:
# Status inicial do R-A01: em espera
# Status inicial do R-B02: em espera
# Robo R-A01 ativado!
# Status atual do R-A01: ativo
# Status atual do R-B02: (não foi alterado): em espera

# %% [markdown]
# [Documentação Oficial Python: Classes – seção oficial do tutorial do Python sobre POO](https://fit-tecnologia.org.br/ava/mod/page/view.php?id=68&forceview=1#:~:text=Documenta%C3%A7%C3%A3o%20Oficial%20Python%3A%20Classes%20%E2%80%93%20se%C3%A7%C3%A3o%20oficial%20do%20tutorial%20do%20Python%20sobre%20POO)

# %%
#Exemplo:Simulação de sensor de vibração
class SensorVibracao:
  def __init__(self, id_sensor):
    self.id_sensor = id_sensor
    self.Vibracao_atual = 2.3 #em mm/s RMS
    self.limite_maximo = 4.5 # em mm/s RMS

#Criamos uma instancia do sensor
sensor_Vibracao = SensorVibracao("Sensor-Motor-01")

#1. Acessando um tributo para verificar a vibracao atual
print(f"Vibracao atual: {sensor_Vibracao.Vibracao_atual} mm/s")

#2. modificando um atributo para definir um novo limite
print("Ajustando limite maximo de vibração...")
sensor_Vibracao.limite_maximo = 5.0

#3. Verificando a mudança
print(f"Novo limite maximo de vibração: {sensor_Vibracao.limite_maximo} mm/s")
# Out:
# Vibracao atual: 2.3 mm/s
# Ajustando limite maximo de vibração...
# Novo limite maximo de vibração: 5.0 mm/s

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Esteira:
  def __init__(self, id_esteira):
    self.id = id_esteira
    self.status = "parada" #Status inicial

  def ligar(self):
    self.status = "movendo"
    print(f"Esteira {self.id}: movendo.")

  def parar (self):
    self.status = "parada"
    print(f"Esteira {self.id}: parada para acesso do robo.")

class Robo:
  def __init__(self, id_robo):
    self.id = id_robo
    self.status = "em espera"

  def pegar_peca(self, esteira_alvo):
    print(f"Robo {self.id}: iniciando operação de coleta.")
    self.status = "trabalhando"

    #interação: o robo Acessa o atributo esteira
    if esteira_alvo.status == "movendo":
      print(f"robo {self.id}: a esteira esta movendo. solicitando parada...")
      #interação: o robo chama o metodo da esteira
      esteira_alvo.parar()

    print (f"robo {self.id}: pegando peca da esteira {esteira_alvo.id}.")
    #Logica para pegar a peça aqui...
    print (f"robo {self.id}: peça coletada com sucesso.")
    self.status = "em espera"

# %%
#simulação

esteira_producao = Esteira("EST-01")
robo_braco = Robo("RB-01")

#1. Ligamos a esteira
esteira_producao.ligar()

#2. o robo tenta pegar a peca, interagindo com a esteira
robo_braco.pegar_peca(esteira_producao)

#3. verificamos o estado final da esteira
print (f"Estados final da esteira {esteira_producao.id}: {esteira_producao.status} ")
# Out:
# Esteira EST-01: movendo.
# Robo RB-01: iniciando operação de coleta.
# robo RB-01: a esteira esta movendo. solicitando parada...
# Esteira EST-01: parada para acesso do robo.
# robo RB-01: pegando peca da esteira EST-01.
# robo RB-01: peça coletada com sucesso.
# Estados final da esteira EST-01: parada

# %% [markdown]
# #Criando uma nova classe e instanciando um objeto:
#
# >Contexto Teórico: Modelando a Realidade para o Controle de Processos
#
# Nosso desafio é criar um "gêmeo digital" dessa válvula. Precisamos de um modelo em software (uma classe) que contenha suas informações essenciais (ID, tipo de fluido, abertura atual) e possa realizar suas ações fundamentais (ajustar a abertura, relatar seu estado). Criar esta classe é o primeiro passo para construir um sistema SCADA ou um painel de controle virtual.

# %%
#Passo 1: A palavra-Chave 'class' - o inicio do projeto

class ValvulaControle:
  """
      Esta classe modela uma valvula de controle proporcional,
      um componente crucial em sistemas de automoção industrial para
      regular o fluxo de fluidos.
  """

  #Passo 02: o construtor '__init__' - a linha de montagem do Objeto

  def __init__(self, id_valvula, tipo_fluido):
    #Passo 3: Atributos - As propriedades de cada Valvula
    print(f"Criando nova válvula com ID:{id_valvula}")
    self.id_valvula = id_valvula
    self.tipo_fluido = tipo_fluido
    self.abertura_percentual = 0.0
    self.status = "operacional"

  #Passo 4: metodos - os componentes da valvula
  def ajustar_abertura(self, percentual_desejado):
    """ajustar a posição da valvula para um novo percentual. """
    if 0 <= percentual_desejado <= 100:
      self.abertura_percentual = float(percentual_desejado)
      print(f"[{self.id_valvula}] Abertura da valvula ajustada para {self.abertura_percentual}%")

  def relatar_estado(self):
    """Retornar uma string formatada com o estado atual da valvula. """
    estado = (f"--- Relatorio da Válvula {self.id_valvula} ---\n"
              f" Fluido: {self.tipo_fluido}\n"
              f"Abertura: {self.abertura_percentual}%\n"
              f" Status: {self.status}\n"
              f"---------------------------------------------")
    return estado
# ------------- Fim do projeto (classe)-----
#Passo 5: Instanciação - Fabricando os objetos

print ("--- Iniciando sistema de controle de fluidos ---")
valvula_agua_tanque = ValvulaControle("V-101", "Água Resfriada")
Valvula_ar_compressor = ValvulaControle("V-25A", "Ar comprimido")
print ("-" *20)

#Passo 6 : Utilização -Colocando os objetos para trabalhar
valvula_agua_tanque.ajustar_abertura(75.5)
Valvula_ar_compressor.ajustar_abertura(100)

print (valvula_agua_tanque.relatar_estado())
print (Valvula_ar_compressor.relatar_estado())

# Tentando um ajuste invalido

valvula_agua_tanque.ajustar_abertura(110)
# Out:
# --- Iniciando sistema de controle de fluidos ---
# Criando nova válvula com ID:V-101
# Criando nova válvula com ID:V-25A
# --------------------
# [V-101] Abertura da valvula ajustada para 75.5%
# [V-25A] Abertura da valvula ajustada para 100.0%
# --- Relatorio da Válvula V-101 ---
#  Fluido: Água Resfriada
# Abertura: 75.5%
#  Status: operacional
# ---------------------------------------------
# --- Relatorio da Válvula V-25A ---
#  Fluido: Ar comprimido
# Abertura: 100.0%
#  Status: operacional
# ---------------------------------------------

# %% [markdown]
# #Trabalhando com arquivos CSV, TXT e JSON

# %%
#exemplo de leitura de arquivos

#1 Abrindo e lendo um arquivo TXT

print ("Leitura de arquivo TXT: ")
with open ('dados_sensores.txt', 'r', encoding='ISO-8859-1') as arquivo_txt:
  conteudo_txt = arquivo_txt.read()
  print (conteudo_txt)
  print("-"*40)

#2 abrindo e lendo um arquivo csv

import csv

print ("Leitura de arquivo CSV: ")
with open ('dados_sensores.csv', 'r', encoding='ISO-8859-1') as arquivo_csv:
  leitor_csv = csv.reader(arquivo_csv)
  for linha in leitor_csv:
    print (linha)
print("-"*40)

#abrindo e lendo um arquivo json

import json

print("leitura de arquivo json:")
with open('dados_sensores.json', 'r', encoding = 'utf-8') as arquivo_json:
  dados_json = json.load(arquivo_json)
  print(dados_json)
print("-"*40)
# Out:
# Leitura de arquivo TXT:
# Leitura 1 - Temperatura: 26.39 C
# Leitura 2 - Temperatura: 22.23 C
# Leitura 3 - Temperatura: 28.92 C
# Leitura 4 - Temperatura: 20.3 C
# Leitura 5 - Temperatura: 20.27 C
#
# ----------------------------------------
# Leitura de arquivo CSV:
# ['Data', 'Hora', 'Temperatura (Â°C)', 'Velocidade (m/s)']
# ['2025-09-09', '16:19:21', '26.39', '16.88']
# ['2025-09-09', '16:20:21', '22.23', '70.24']
# ['2025-09-09', '16:21:21', '28.92', '21.52']
# ['2025-09-09', '16:22:21', '20.30', '31.40']
# ['2025-09-09', '16:23:21', '20.27', '29.91']
# ----------------------------------------
# leitura de arquivo json:
# ...

# %%
#exemplo criando arquivos csv e json
import csv
import json

#simulação de leituras de temperatura
temperaturas = [22.5, 23.0, 22.8, 23.2, 22.9]

#1 Gravar temperaturas em csv
with open('temperaturas.csv', 'w', newline='', encoding='utf-8') as f:
  writer = csv.writer(f)
  writer.writerow(['leitura', 'temperatura'])
  for i, temp in enumerate(temperaturas, 1):
    writer.writerow([i, temp])

#2 criar lista de dicionario para json
dados_json = [{'leitura': i+1, "temperatura":temp} for i, temp in enumerate(temperaturas)]

#3 salvar dados em json
with open('relatorio.json', 'w', encoding='utf-8') as f:
  json.dump(dados_json, f, ensure_ascii=False, indent=2)

# %% [markdown]
# #Lendo Dados de Arquivos com Python
# >Vamos simular um cenário comum em sistemas embarcados e IoT: ao iniciar, nosso programa precisa carregar sua configuração de um arquivo JSON, ler um ID de um arquivo de texto simples e processar um log de dados de sensores de um arquivo CSV.

# %% [markdown]
# Contexto Teórico: A Inicialização de um Sistema Inteligente
# Um dispositivo de borda (edge device), como um gateway de IoT em uma fábrica, não possui dados "hard-coded" (fixos no código). Ele precisa ser flexível. Ao ligar, ele executa uma rotina de inicialização:
#
# Lê um arquivo de configuração para saber a qual rede Wi-Fi se conectar e para qual servidor enviar dados.
# Lê um arquivo de log para verificar se houve falhas na última execução.
# Processa dados históricos de sensores para calibragem inicial.

# %%
#Importando os modulos necessarios para csv e json

import csv
import json

#--- cenario: Simulação de inicialização de um gatway de iot ---
#Primeiro, vamos simular a existencia dos arquivos que nosso programa irá ler

#Arquivo 1: device_id.txt (texto simples)
with open  ("device_id.txt", "w") as f:
  f.write("GW-I40-BR-031")

#arquivo 2: sensor_log.csv (csv)
with open ("sensor_log.csv", "w", newline="") as f:
  writer = csv.writer(f)
  writer.writerow(["timestamp", "Vibration_x", "vibration_y"])
  writer.writerow(['1678886400', "0,51", "1.20"])
  writer.writerow(["1678886401", "0.53", "1.22"])
  writer.writerow(["1678886402", "0.95", "1.89"])#anomalia

#arquivo 3: config.json (json)
config_data = {
    "network":{
        "wifi_ssid": "FactoryFloor_Net",
        "wifi_pass": "senhaSuperSegura123"
    },
    "server":{
        "host": "data.minhafabrica.com",
        "port": 8883
    },
    "active_sensors": ["temperature", "Vibration"]
}
with open("config.json", "w") as f:
  json.dump(config_data, f, indent=4)

print("--- Arquivo de simulação criado. iniciando leitura. ---\n")

#1 lendo arquivo de texto simples (.txt)
print("--- 1. Lendo Id do dispositivo de 'device_id.txt' ---")

try:
    with open("device_id.txt", "r") as file:
        device_id = file.read().strip()
        print(f"ID do do gatway lido com sucesso: {device_id}\n")
except FileNotFoundError:
    print("ERRO: Arquivo de ID não encontrado!\n")

#2. Lendo arquivo csv
print("--- 2. Processando log de sensor de 'sensor_log.csv' ---")

try:
    with open("sensor_log.csv", "r") as file:
        csv_reader = csv.reader(file)
        reader = next(csv_reader)
        print(f"Cabeçalho do arquivo CSV: {reader}\n")
        for row in csv_reader:
            timestamp = int(row[0])
            vib_x = float(row[1].replace(',', '.'))
            if vib_x >0.9:
                print(f"Alerta: Vibração anomala detectada no timestamp {timestamp}: {vib_x}")
    print("\n")
except FileNotFoundError:
  print("Erro: Arquivo de log do sensor não encontrado!\n")

#3. Lendo arquivo json
print("---3. carregando configurações de 'config.json' ---")
try:
  with open("config.json", "r") as file:
    config = json.load(file)
    server_host = config["server"]["host"]
    active_sensors = config["active_sensors"]
    print(f"Gateway configurado para enviar dados para: {server_host}")
    print(f"Sensores ativos na configuração: {active_sensors}\n")
except FileNotFoundError:
  print("Erro: Arquivo de configuração não encontrado!\n")
except json.JSONDecodeError:
  print("Erro: Arquivo de configuração está mal formatado (não é um json valido)!\n")
# Out:
# --- Arquivo de simulação criado. iniciando leitura. ---
#
# --- 1. Lendo Id do dispositivo de 'device_id.txt' ---
# ID do do gatway lido com sucesso: GW-I40-BR-031
#
# --- 2. Processando log de sensor de 'sensor_log.csv' ---
# Cabeçalho do arquivo CSV: ['timestamp', 'Vibration_x', 'vibration_y']
#
# Alerta: Vibração anomala detectada no timestamp 1678886402: 0.95
#
#
# ---3. carregando configurações de 'config.json' ---
# Gateway configurado para enviar dados para: data.minhafabrica.com
# Sensores ativos na configuração: ['temperature', 'Vibration']

# %% [markdown]
# para saber mais
#
# [Função open](https://docs.python.org/3/library/functions.html#open),
# [Módulo csv](https://docs.python.org/3/library/csv.html),
# [Módulo json](https://docs.python.org/3/library/json.html)
